# %%
try:
    # %load_ext autotime
except:
    # !pip install ipython-autotime
    # %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 707 µs (started: 2025-05-09 12:57:47 +05:30)

# %%
def sbox(inp):
    s =  []
    return s[inp]


def invsbox(inp):
    s = []
    return s[inp]


def intermediate(pt, keyguess):
    return sbox(pt ^ keyguess)

HW = [bin(n).count("1") for n in range(0, 256)]
# Out:
# time: 1.58 ms (started: 2025-05-09 12:57:52 +05:30)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tnrange
from scipy.stats import linregress
#import seaborn as sns
import time
#import rich as r
import pandas as pd
from IPython.display import clear_output # type: ignore
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import brewer

# load the .npy files
#known_keys = np.load('cw_traces/known_keys.npy')
textin_array = np.load('plaintext.npy')
trace_array = np.load('traces.npy')

#print(known_keys.shape)
print(textin_array.shape)
print(trace_array.shape)
# Out:
# (10000, 16)
# (10000, 12000)
# time: 206 ms (started: 2025-05-09 13:12:28 +05:30)

# %% [markdown]
# # CPA

# %%
fmt = "{:02X}<br>{:.3f}"
def format_stat(stat):
    return str(fmt.format(stat[0], stat[1]))

def color_corr_key(row):
    # print(len(row))
    ret = [""] * len(row)
    for i, bnum in enumerate(row):
        if i == 0:
            ret[i] = "color: green"
        else:
            ret[i] = "color: red"
    return ret
# Out:
# time: 1.14 ms (started: 2025-05-09 12:58:12 +05:30)

# %% [markdown]
# Attacking Using Linear Regression Correlation Technique

# %%
##The below code implements correlation using Linear Regression Techinque---> Result is low correlation

from scipy.stats import pearsonr
key_guess = []
numtraces = trace_array.shape[0]

numpoints = trace_array.shape[1]
start_point = 400
end_point = 1500

crvs = np.zeros((16, 256, numpoints))
HW_matrix = np.zeros((numtraces, 256), dtype=np.uint8)

printable = []    # for printing the top guessed keys


for subkey in tnrange(0, 16, desc="Attacking Subkey"):
    temp = []    # it holds the [(key_guess1, correlation_value),(key_guess2, correlation_value),..]
    for kguess in tnrange(0, 256, desc="Generating Hamming Weights"):
        # Generate the hamming weight for each possible keybyte
        for trace_no in range(numtraces):
            iv = intermediate(textin_array[trace_no][subkey], kguess)
            HW_matrix[trace_no, kguess] = HW[iv]

        # correlate the trace with the hamming weights
        for point in range(start_point, end_point):
            hw = HW_matrix[:, kguess]
            trc = trace_array[:, point]
            crvs[subkey, kguess, point] = np.abs(linregress(hw, trc).slope)

        temp.append((kguess, np.max(crvs[subkey, kguess])))

    temp.sort(key = lambda x: -x[1])  # sort temp by dom value
    printable.append(temp)  # add the data in list
    df = pd.DataFrame(printable).transpose()

    key_guess.append(crvs[subkey].max(axis=1).argmax())

    clear_output(wait=True)  # clear the previous output
    display(df.head().style.format(format_stat).apply(color_corr_key, axis=0))  # display the current status
# Out:
# <style type="text/css">
# #T_d5b5e_row0_col0, #T_d5b5e_row0_col1, #T_d5b5e_row0_col2, #T_d5b5e_row0_col3, #T_d5b5e_row0_col4, #T_d5b5e_row0_col5, #T_d5b5e_row0_col6, #T_d5b5e_row0_col7, #T_d5b5e_row0_col8, #T_d5b5e_row0_col9, #T_d5b5e_row0_col10, #T_d5b5e_row0_col11, #T_d5b5e_row0_col12, #T_d5b5e_row0_col13, #T_d5b5e_row0_col14, #T_d5b5e_row0_col15 {
#   color: green;
# }
# ...

# %%
##The below code implements correlation using Pearson Techinque---> Result is high correlation and correct key guess

import numpy as np
import pandas as pd
from IPython.display import display, clear_output

# AES S-box (256 entries)
AES_SBOX = np.array([
    
], dtype=np.uint8)

def hamming_weight(x):
    return bin(x).count("1")

# Highlight the top correlation in green
def color_corr_key(column):
    values = [float(cell.split(':')[1]) for cell in column]
    max_corr = max(values)
    return [
        'background-color: lightgreen; font-weight: bold' if abs(float(cell.split(':')[1]) - max_corr) < 1e-8 else ''
        for cell in column
    ]

def cpa_aes_top5(traces, plaintexts, start=0, end=None):
    if end is None:
        end = traces.shape[1]

    num_traces, num_points = traces.shape
    trace_window = traces[:, start:end].astype(np.float32)
    trace_mean = np.mean(trace_window, axis=0)
    trace_std = np.std(trace_window, axis=0)

    key_guess = []
    printable = []

    for subkey in range(16):
        temp = []

        for kguess in range(256):
            hw = np.array([
                hamming_weight(AES_SBOX[pt ^ kguess])
                for pt in plaintexts[:, subkey]
            ], dtype=np.float32)

            hw_mean = np.mean(hw)
            hw_std = np.std(hw)
            if hw_std == 0:
                continue

            hw_centered = (hw - hw_mean).reshape(-1, 1)
            cov = np.mean(hw_centered * (trace_window - trace_mean), axis=0)
            denom = hw_std * trace_std

            corr = np.zeros_like(cov)
            mask = denom != 0
            corr[mask] = cov[mask] / denom[mask]

            temp.append((kguess, np.max(np.abs(corr))))

        temp.sort(key=lambda x: -x[1])
        top5 = [f"{v[0]:02X}:{v[1]:.5f}" for v in temp[:5]]

        printable.append(top5)
        key_guess.append(temp[0][0])

        # Display update
        df = pd.DataFrame(printable, columns=[f"Top-{i+1}" for i in range(5)]).transpose()
        clear_output(wait=True)
        display(df.style.apply(color_corr_key, axis=0))

    print("\nRecovered Key:")
    print(" ".join(f"{k:02X}" for k in key_guess))
    return key_guess

cpa_aes_top5(trace_array, textin_array)
# Out:
# <style type="text/css">
# #T_05fc7_row0_col0, #T_05fc7_row0_col1, #T_05fc7_row0_col2, #T_05fc7_row0_col3, #T_05fc7_row0_col4, #T_05fc7_row0_col5, #T_05fc7_row0_col6, #T_05fc7_row0_col7, #T_05fc7_row0_col8, #T_05fc7_row0_col9, #T_05fc7_row0_col10, #T_05fc7_row0_col11, #T_05fc7_row0_col12, #T_05fc7_row0_col13, #T_05fc7_row0_col14, #T_05fc7_row0_col15 {
#   background-color: lightgreen;
#   font-weight: bold;
# }
# </style>
# <table id="T_05fc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05fc7_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_05fc7_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_05fc7_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_05fc7_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_05fc7_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_05fc7_level0_col5" class="col_heading level0 col5" >5</th>
# ...

# %%
for subkey in range(16):
    plt.figure(figsize=(20,2))

    for guessed_key in range(256):
        sns.scatterplot(x=range(400), y=crvs[subkey, guessed_key ,400:800])

        plt.title(f"Sub Keys {subkey}")
    if subkey == 15:
        plt.xlabel("Time")
    plt.ylabel("correlation")
    plt.show()

# %%
selected_subkey = 0

plt.figure(figsize=(20, 8))
sns.scatterplot(x=range(256), y=crvs[selected_subkey, :, :].max(axis=1))

for key in range(256):
    max_crv = crvs[selected_subkey, :, :].max()
    if crvs[selected_subkey, key, :].max() == max_crv:
        plt.text(x=key + 1, y=max_crv + 0.0001, s=str(key))

plt.title("Correlation vs Guessed Keys")
plt.xlabel("Guessed Keys")
plt.ylabel("Correlation Coefficient")
plt.show()

# %%
fig, axs = plt.subplots(nrows=16, ncols=1, figsize=(20, 30))
plt.subplots_adjust(hspace=0.5)
colors = plt.rcParams["axes.prop_cycle"]()
fig.suptitle("subkey vs correlation values", fontsize=18, y=0.95)

for _, ax in enumerate(axs):
    c = next(colors)["color"]
    ax.scatter(range(256), crvs[_,:,:].max(axis=1), color=c, alpha=1)
    _crvs = crvs[_,:,:].max(axis=1)
    for i in range(256):
        max_corr = _crvs.max()
        if _crvs[i] == max_corr:
            ax.text(x=i + 1, y=max_corr - 0.001, s=str(i))
    ax.set_title("Subkey {}".format(_))
# Out:
# time: 1.13 s (started: 2025-05-09 11:03:15 +05:30)

# %%
# %unload_ext autotime
